# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Get the data

# %%
filename = 'datasets/mtcars.csv'

df = pd.read_csv(filename, sep=',')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
names = df['name']
names
# Out:
# 0                 chevrolet chevelle malibu
# 1                         buick skylark 320
# 2                        plymouth satellite
# 3                             amc rebel sst
# 4                               ford torino
# 5                          ford galaxie 500
# 6                          chevrolet impala
# 7                         plymouth fury iii
# 8                          pontiac catalina
# 9                        amc ambassador dpl
# 10                      dodge challenger se
# 11                       plymouth 'cuda 340
# 12                    chevrolet monte carlo
# 13                  buick estate wagon (sw)
# 14                    toyota corona mark ii
# 15                          plymouth duster
# 16                               amc hornet
# 17                            ford maverick
# 18                             datsun pl510
# 19             volkswagen 1131 deluxe sedan
# 20                              peugeot 504
# ...

# %%
type(names)
# Out:
# pandas.core.series.Series

# %%
list(names)
# Out:
# ['chevrolet chevelle malibu',
#  'buick skylark 320',
#  'plymouth satellite',
#  'amc rebel sst',
#  'ford torino',
#  'ford galaxie 500',
#  'chevrolet impala',
#  'plymouth fury iii',
#  'pontiac catalina',
#  'amc ambassador dpl',
#  'dodge challenger se',
#  "plymouth 'cuda 340",
#  'chevrolet monte carlo',
#  'buick estate wagon (sw)',
#  'toyota corona mark ii',
#  'plymouth duster',
#  'amc hornet',
#  'ford maverick',
#  'datsun pl510',
#  'volkswagen 1131 deluxe sedan',
#  'peugeot 504',
#  'audi 100 ls',
#  'saab 99e',
#  'bmw 2002',
#  'amc gremlin',
#  'ford f250',
#  'chevy c20',
#  'dodge d200',
#  'hi 1200d',
#  'datsun pl510',
#  'chevrolet vega 2300',
#  'toyota corona',
#  'ford pinto',
#  'amc gremlin',
#  'plymouth satellite custom',
#  'chevrolet chevelle malibu',
#  'ford torino 500',
#  'amc matador',
#  'chevrolet impala',
#  'pontiac catalina brougham',
#  'ford galaxie 500',
#  'plymouth fury iii',
#  'dodge monaco (sw)',
#  'ford country squire (sw)',
# ...

# %% [markdown]
# ## Create a dataframe

# %%
d = {'country':'usa', 'short_code':'US'}
d['short_code']
# Out:
# 'US'

# %%
origins = pd.DataFrame([
    {'country':'usa', 'short_code':'US'},
    {'country':'europe', 'short_code':'EU'},
    {'country':'japan', 'short_code':'JP'},
])

origins
# Out:
#   country short_code
# 0     usa         US
# 1  europe         EU
# 2   japan         JP

# %%
type(origins)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exploration

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %%
df.tail(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                        name
# 388          82     usa  chrysler lebaron medallion
# 389          82     usa              ford granada l
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
df.count()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      392
# weight          398
# acceleration    398
# model_year      398
# origin          398
# name            398
# dtype: int64

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.rename(columns = {'name':'model'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   model         398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=398, step=1),
#  Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#         'acceleration', 'model_year', 'origin', 'model'],
#        dtype='object')]

# %%
list(df.columns)
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'model']

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df['mpg'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df['mpg'].plot(kind = 'hist', bins = 20, title = 'MPG')
# Out:
# <AxesSubplot:title={'center':'MPG'}, ylabel='Frequency'>

# %%
list(df['origin'].unique())
# Out:
# ['usa', 'japan', 'europe']

# %%
df['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df['origin'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Type conversion

# %%
df['model'] = df['model'].astype('string')
df['origin'] = df['origin'].astype('string')

# %%
df['weight'] = df['weight'].astype('float')

# %%
df['mpg'] = df['mpg'].astype('int')

# %%
df['cylinders'] = df['cylinders'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    int64
#  1   cylinders     398 non-null    category
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    string
#  8   model         398 non-null    string
# dtypes: category(1), float64(4), int64(2), string(2)
# memory usage: 25.6 KB

# %% [markdown]
# ## Missing values

# %%
df[df['horsepower'].isna()]
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 32    25         4          98.0         NaN  2046.0          19.0
# 126   21         6         200.0         NaN  2875.0          17.0
# 330   40         4          85.0         NaN  1835.0          17.3
# 336   23         4         140.0         NaN  2905.0          14.3
# 354   34         4         100.0         NaN  2320.0          15.8
# 374   23         4         151.0         NaN  3035.0          20.5
#
#      model_year  origin                 model
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
df.dropna(axis = 0, subset = 'horsepower')
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %% [markdown]
# ## Index

# %%
df
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %%
df.set_index('model')
# Out:
#                                       mpg cylinders  displacement  horsepower  \
# model
# chevrolet chevelle malibu              18         8         307.0       130.0
# buick skylark 320                      15         8         350.0       165.0
# plymouth satellite                     18         8         318.0       150.0
# amc rebel sst                          16         8         304.0       150.0
# ford torino                            17         8         302.0       140.0
# ford galaxie 500                       15         8         429.0       198.0
# chevrolet impala                       14         8         454.0       220.0
# plymouth fury iii                      14         8         440.0       215.0
# pontiac catalina                       14         8         455.0       225.0
# amc ambassador dpl                     15         8         390.0       190.0
# dodge challenger se                    15         8         383.0       170.0
# ...

# %%
df.reset_index().set_index(['origin','model']).sort_values(['origin','model'])
# Out:
#                                              index  mpg cylinders  \
# origin model
# europe audi 100 ls                              21   24         4
#        audi 100ls                              119   20         4
#        audi 100ls                              177   23         4
#        audi 4000                               317   34         4
#        audi 5000                               274   20         5
#        audi 5000s (diesel)                     327   36         5
#        audi fox                                141   29         4
#        bmw 2002                                 23   26         4
#        bmw 320i                                242   21         4
#        fiat 124 sport coupe                    114   26         4
#        fiat 124 tc                             148   26         4
#        fiat 124b                                52   30         4
#        fiat 128                                117   29         4
# ...

# %% [markdown]
# ## indexing and slicing

# %%
df[   ['origin','model']    ]
# Out:
#      origin                                 model
# 0       usa             chevrolet chevelle malibu
# 1       usa                     buick skylark 320
# 2       usa                    plymouth satellite
# 3       usa                         amc rebel sst
# 4       usa                           ford torino
# 5       usa                      ford galaxie 500
# 6       usa                      chevrolet impala
# 7       usa                     plymouth fury iii
# 8       usa                      pontiac catalina
# 9       usa                    amc ambassador dpl
# 10      usa                   dodge challenger se
# 11      usa                    plymouth 'cuda 340
# 12      usa                 chevrolet monte carlo
# 13      usa               buick estate wagon (sw)
# 14    japan                 toyota corona mark ii
# 15      usa                       plymouth duster
# 16      usa                            amc hornet
# 17      usa                         ford maverick
# ...

# %%
df[    df['origin']=='europe'    ]
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 19    26         4          97.0        46.0  1835.0          20.5
# 20    25         4         110.0        87.0  2672.0          17.5
# 21    24         4         107.0        90.0  2430.0          14.5
# 22    25         4         104.0        95.0  2375.0          17.5
# 23    26         4         121.0       113.0  2234.0          12.5
# 50    28         4         116.0        90.0  2123.0          14.0
# 51    30         4          79.0        70.0  2074.0          19.5
# 52    30         4          88.0        76.0  2065.0          14.5
# 55    27         4          97.0        60.0  1834.0          19.0
# 59    23         4          97.0        54.0  2254.0          23.5
# 76    18         4         121.0       112.0  2933.0          14.5
# 77    22         4         121.0        76.0  2511.0          18.0
# 78    21         4         120.0        87.0  2979.0          19.5
# ...

# %%
df[df['origin'].isin(['europe','usa'])]
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %%
df[(df['origin']=='europe') | (df['origin']=='usa')]
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %%
df.loc[   df['origin']=='europe'   ,    ['origin','model','model_year']   ]
# Out:
#      origin                            model  model_year
# 19   europe     volkswagen 1131 deluxe sedan          70
# 20   europe                      peugeot 504          70
# 21   europe                      audi 100 ls          70
# 22   europe                         saab 99e          70
# 23   europe                         bmw 2002          70
# 50   europe                        opel 1900          71
# 51   europe                      peugeot 304          71
# 52   europe                        fiat 124b          71
# 55   europe             volkswagen model 111          71
# 59   europe                volkswagen type 3          72
# 76   europe                  volvo 145e (sw)          72
# 77   europe              volkswagen 411 (sw)          72
# 78   europe                 peugeot 504 (sw)          72
# 79   europe                  renault 12 (sw)          72
# 102  europe          volkswagen super beetle          73
# ...

# %% [markdown]
# ## Nieuw kolom

# %%
df['kml'] = df['mpg'] * 0.425143707

# %%
df
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %%
df['description'] = df['model'] + ' - ' + df['origin']

# %%
df
# Out:
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# 9     15         8         390.0       190.0  3850.0           8.5
# 10    15         8         383.0       170.0  3563.0          10.0
# 11    14         8         340.0       160.0  3609.0           8.0
# 12    15         8         400.0       150.0  3761.0           9.5
# ...

# %%
df['weight_class'] = pd.cut(df['weight'], 
                            bins = [0,2000, 4000,10000], 
                            labels = ['light','normal','heavy'])

# %%
df['weight_class'].value_counts()
# Out:
# normal    290
# heavy      64
# light      44
# Name: weight_class, dtype: int64

# %%
df['weight'].plot(kind = 'hist', bins = [0, 2000, 4000, 10000])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['weight_class'].value_counts().plot(kind = 'bar')

plt.savefig('mpg_hist.png')

# %% [markdown]
# ## Aggregatie

# %%
df_mean_weights = df[['origin','weight']].groupby('origin').mean()
df_mean_weights
# Out:
#              weight
# origin
# europe  2423.300000
# japan   2221.227848
# usa     3361.931727

# %%
df.groupby('origin')[['weight','horsepower']].mean()
# Out:
#              weight  horsepower
# origin
# europe  2423.300000   80.558824
# japan   2221.227848   79.835443
# usa     3361.931727  119.048980

# %%
totalen = df.groupby('origin')['mpg','weight'].agg(['min','max','mean','median'])
totalen
# Out:
# /var/folders/03/yj771kx92fj0g_3xbr70x6980000gn/T/ipykernel_1863/4138607576.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   totalen = df.groupby('origin')['mpg','weight'].agg(['min','max','mean','median'])
#        mpg                        weight
#        min max       mean median     min     max         mean  median
# origin
# europe  16  44  27.742857   26.5  1825.0  3820.0  2423.300000  2240.0
# japan   18  46  30.240506   31.0  1613.0  2930.0  2221.227848  2155.0
# usa      9  39  19.927711   18.0  1800.0  5140.0  3361.931727  3365.0

# %%
totalen.to_csv('export_totalen.csv', sep=',')

# %%
df.merge(totalen, left_on='origin', right_index=True)
# Out:
# /var/folders/03/yj771kx92fj0g_3xbr70x6980000gn/T/ipykernel_1863/4197439869.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   df.merge(totalen, left_on='origin', right_index=True)
#      mpg cylinders  displacement  horsepower  weight  acceleration  \
# 0     18         8         307.0       130.0  3504.0          12.0
# 1     15         8         350.0       165.0  3693.0          11.5
# 2     18         8         318.0       150.0  3436.0          11.0
# 3     16         8         304.0       150.0  3433.0          12.0
# 4     17         8         302.0       140.0  3449.0          10.5
# 5     15         8         429.0       198.0  4341.0          10.0
# 6     14         8         454.0       220.0  4354.0           9.0
# 7     14         8         440.0       215.0  4312.0           8.5
# 8     14         8         455.0       225.0  4425.0          10.0
# ...

# %% [markdown]
# ## group concat

# %%
df.groupby('origin', as_index=False)['cylinders'].agg(set)
# Out:
#    origin  cylinders
# 0  europe  {4, 5, 6}
# 1   japan  {3, 4, 6}
# 2     usa  {8, 4, 6}

# %%
df.groupby('origin', as_index=False)['cylinders'].agg(lambda a: ','.join(map(str, sorted(set(a)))))
# Out:
#    origin cylinders
# 0  europe     4,5,6
# 1   japan     3,4,6
# 2     usa     4,6,8

# %%
df['make'] = df['model'].str.extract(r'^(\w+)\s.*')

# %%
pd.groupby('make', as_index=False)['cylinders'].agg(lambda a: ','.join(map(str, sorted(set(a)))))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 pd.groupby('make', as_index=False)['cylinders'].agg(lambda a: ','.join(map(str, sorted(set(a)))))
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'groupby'

# %% [markdown]
# ## Pivot table

# %%
pd.pivot_table(df,
               index='origin', 
               columns='cylinders',
               values='mpg', 
               aggfunc='mean')

# %% [markdown]
# ## conditional style

# %%
def colorize(x):
    styles = []
    for v in x:
        if x < 1000:
            pass
        elif x < 2000:
            style =  "background: green"
        elif x < 3000:
            style =  "background: yellow"
        else:
            style =  "background: red"
        styles.append(style)
    return styles
            
# df[['weight']].style.apply(colorize)

df[['weight']].style.apply(lambda x: ["background: #eeaaaa" if v > 4000 else "" for v in x])
