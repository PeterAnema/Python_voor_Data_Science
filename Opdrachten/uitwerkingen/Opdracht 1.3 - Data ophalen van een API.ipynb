# %% [markdown]
# # Opdracht 1.3 - Data ophalen van een API

# %%
import requests

# %% [markdown]
# ### Openweathermap.org
#
# http://api.openweathermap.org

# %%
city = 'Amsterdam'

url  = 'http://api.openweathermap.org/data/2.5/weather'
url += '?appid=d1526a9039658a6f76950cff21823aff'
url += '&units=metric'
url += '&mode=json'
url += '&lang=nl'
url += '&q=' + city

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=d1526a9039658a6f76950cff21823aff&units=metric&mode=json&lang=nl&q=Amsterdam

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# {"coord":{"lon":4.8897,"lat":52.374},"weather":[{"id":802,"main":"Clouds","description":"licht bewolkt","icon":"03d"}],"base":"stations","main":{"temp":16.39,"feels_like":16.1,"temp_min":15.47,"temp_max":17.72,"pressure":1017,"humidity":77},"visibility":10000,"wind":{"speed":2.06,"deg":220},"clouds":{"all":40},"dt":1652773452,"sys":{"type":2,"id":2012552,"country":"NL","sunrise":1652758935,"sunset":1652815898},"timezone":7200,"id":2759794,"name":"Amsterdam","cod":200}

# %%
d = r.json()

temperature = d['main']['temp']
weather = d['weather'][0]['description'] 

print('Het is %d°C en %s in %s' % (temperature, weather, city))

print(f'Het is {temperature} graden en {weather} in Amsterdam.')
# Out:
# Het is 16°C en licht bewolkt in Amsterdam
# Het is 16.39 graden en licht bewolkt in Amsterdam.

# %%
d
# Out:
# {'coord': {'lon': 4.8897, 'lat': 52.374},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'licht bewolkt',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 16.39,
#   'feels_like': 16.1,
#   'temp_min': 15.47,
#   'temp_max': 17.72,
#   'pressure': 1017,
#   'humidity': 77},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 220},
#  'clouds': {'all': 40},
#  'dt': 1652773452,
#  'sys': {'type': 2,
#   'id': 2012552,
#   'country': 'NL',
#   'sunrise': 1652758935,
#   'sunset': 1652815898},
#  'timezone': 7200,
#  'id': 2759794,
#  'name': 'Amsterdam',
#  'cod': 200}
